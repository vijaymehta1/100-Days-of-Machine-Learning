# %%
import numpy as np
import pandas as pd
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('train.csv',usecols=['GarageQual','KitchenQual','FireplaceQu','SalePrice'])

# %%
df
# Out:
#      KitchenQual FireplaceQu GarageQual  SalePrice
# 0             Gd         NaN         TA     208500
# 1             TA          TA         TA     181500
# 2             Gd          TA         TA     223500
# 3             Gd          Gd         TA     140000
# 4             Gd          TA         TA     250000
# ...          ...         ...        ...        ...
# 1455          TA          TA         TA     175000
# 1456          TA          TA         TA     210000
# 1457          Gd          Gd         TA     266500
# 1458          Gd         NaN         TA     142125
# 1459          TA         NaN         TA     147500
#
# [1460 rows x 4 columns]

# %%
df.isnull().mean()*100
# Out:
# KitchenQual     0.000000
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
x = df.drop(columns=['SalePrice'])
y =df['SalePrice']

# %%
# train test spilt
x_train , x_test , y_train , y_test  = train_test_split(x,y,test_size=.2,random_state= 42)

# %%
imputer = SimpleImputer(strategy='constant',fill_value='Missing')

# %%
X_train = imputer.fit_transform(x_train)
X_test = imputer.transform(x_train)

# %%
imputer.statistics_
# Out:
# array(['Missing', 'Missing', 'Missing'], dtype=object)
