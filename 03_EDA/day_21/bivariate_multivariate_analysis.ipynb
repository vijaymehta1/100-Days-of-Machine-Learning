# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic= pd.read_csv('train.csv')
flight = pd.read_csv('flights.csv')

# %% [markdown]
# ### (1) Numerical vs Numerical

# %% [markdown]
# Scatter Plot
# Line Plot
# Regression Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# fig level 
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',style='smoker',size="size",kind='scatter')

# %%
# axis level 
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#lineplot 
titanic
sns.relplot(data=titanic,x='Age',y='Fare',kind='line')

# %%
sns.regplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### (2) Numerical vs Categorical

# %% [markdown]
# Boxplot ⭐ (most important)
# Violin plot
# Bar plot
# Strip / Swarm plot

# %%
# fig level
sns.catplot(kind='box',data=titanic,x='Sex',y='Age',hue="Survived")

# %%
sns.catplot(kind='bar',data=titanic,x='Pclass',y='Age',hue='Survived')

# %% [markdown]
# ### (3) Categorical vs Categorical

# %% [markdown]
# Countplot (with hue)
# Heatmap (crosstab)
# Stacked bar
# clustermap

# %%
sns.heatmap(iris.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(titanic['Pclass'],titanic['Survived']))

# %% [markdown]
# "Passengers in 3rd class had the highest mortality rate, while those in 1st class had significantly higher survival rates. The clustering pattern shows that Pclass 2 and 3 share similar survival characteristics, whereas Pclass 1 stands out with better outcomes, indicating that socio-economic status played a major role in survival."

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# "Petal features (petal length and width) show strong positive correlation and clearly separate the species, making them the most important variables for classification. Setosa is linearly separable from the other species, while versicolor and virginica show partial overlap. Sepal features exhibit weaker relationships and are less effective for distinguishing species."

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
